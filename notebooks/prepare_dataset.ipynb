# %%
import os
import shutil as sh
import numpy as np
import yaml

# %%
dataset_dir = "../data/dataset/"

# %%
experts = ['Ptg1', 'Ptg2', 'Ptg3', 'Stud1', 'Stud2', 'Stud3', 'Stud4']

# %%
os.path.isfile("../data/dataset/Images/Agreement/Explicit/Ptg1/1060.png")
# Out:
# True

# %%
def check_file(path, extention):
    return path.endswith("." + extention) and os.path.isfile(path)

# %%
def strip_images_dir_from_path(initial_path, images_dir):
    sep = os.path.sep
    unstripped = os.path.normpath(initial_path).split(sep)[len(os.path.normpath(images_dir).split(sep)):]
    return os.path.join(*unstripped)

def generate_new_path(initial_path, images_dir, lists_dir):
    meaningful_part = strip_images_dir_from_path(initial_path, images_dir)

    new_path = os.path.join(lists_dir, meaningful_part)
    return new_path

# %%
def generate_lists(source_dir, target_dir, filename, extention):
    for root, dirs, files in os.walk(source_dir, topdown=False):

        for name in dirs:
            dir_path = os.path.join(root, name)

            new_dir_path = generate_new_path(dir_path, source_dir, target_dir)
            if not os.path.exists(new_dir_path):
                os.makedirs(new_dir_path, exist_ok=True)
            files_paths = [os.path.relpath(os.path.join(dir_path,x), start=new_dir_path) for x in os.listdir(dir_path) if check_file(os.path.join(dir_path,x), extention)]
            if len(files_paths):
                with open(os.path.join(new_dir_path, ".".join([filename, "txt"])), "w+") as file:

                        lines_to_write = [str(x) for x in files_paths]
                        lines_to_write.sort()
                        lines_to_write = "\n".join(lines_to_write)
                        file.write(lines_to_write)

            print(new_dir_path, len(files_paths))

# %%
def labels_float_to_int(labels_dir, extention):
    for root, dirs, files in os.walk(labels_dir, topdown=False):

        for name in dirs:
            dir_path = os.path.join(root, name)

            for filename in os.listdir(dir_path):
                file_path = os.path.join(dir_path, filename)
                if check_file(file_path, extention):
                    with open(file_path, "r") as file:
                        lines = file.readlines()
                        new_lines = []
                        for line in lines:
                            line_contents = line.strip().split(" ")
                            line_rounded = tuple(str(np.round(float(x)).astype(int)) for x in line_contents)
                            line_rounded = " ".join(line_rounded)
                            new_lines.append(line_rounded)
                        new_lines = "\n".join(new_lines)
                    with open(file_path, "w") as file:
                        file.write(new_lines)

# %%
import cv2
import albumentations as A
from endoanalysis.datasets import extract_images_and_labels_paths
from endoanalysis.datasets import load_keypoints

# %%
def load_keypoints(file_path, x_size, y_size):
    """
    Load keypoints from a specific file as tuples

    Parameters
    ----------
    file_path : str
        path to the file with keypoints
    x_size : int
        maximum x_value. If keypoint coordinate is greater  or equal
        to x_size, it will be set to be x_size - 1
    y_size : int
        the same as x_size, but for y
    Returns
    -------
    keypoints : list of tuples
        list of keypoint tuples in format (x, y, obj_class)

    Note
    ----
    This function serves as helper for the pointdet.utils.dataset.PointsDataset class
    and probably should be moved there
    """

    keypoints = []

    with open(file_path, "r") as labels_file:
        for line in labels_file:
            line_contents = line.strip().split(" ")
            line_floated = tuple(np.round(float(x)).astype(int) for x in line_contents)
            x_center, y_center, obj_class = tuple(line_floated)
            if x_center >= x_size:
                x_center -= x_size - 1
            if y_center == y_size:
                y_center -= 1
            keypoint = x_center, y_center, obj_class
            keypoints.append(keypoint)

    return keypoints

# %% [raw]
# def fix_keypoints(images_list,labels_list, target_size=(256,256)):
#
#     transorm = A.Compose([A.Resize(height=target_size[0], width=target_size[1])], keypoint_params=A.KeypointParams(format="xy"))
#
#     if type(images_list) != list:
#         images_list = [images_list]
#         labels_list = [labels_list]
#     images_paths = []
#     labels_paths = []
#     for images_list_path, labels_list_path in zip(images_list, labels_list):
#         images_paths_current, labels_paths_current = extract_images_and_labels_paths(images_list_path, labels_list_path)
#         images_paths += images_paths_current
#         labels_paths +=labels_paths_current
#
#     for image_path, labels_path in zip(images_paths, labels_paths):
#         print(image_path)
#         image = cv2.imread(image_path)
#         keypoints = load_keypoints(labels_path, image.shape[1], image.shape[0])
#
#
#         if keypoints:
#             keypoints = np.array(keypoints)
#             coords = keypoints[:,0:2]
#             classes = keypoints[:,2]
#         else:
#             coords = []
#         transformed = transorm(image = image, keypoints=coords)
#
# #         cv2.imwrite(image_path, transformed["image"])
#
#         labels_lines = [
#             " ".join([str(int(y)) for y in label] + [str(class_id)]) + " \n"
#             for label, class_id in zip(transformed["keypoints"], classes)
#             ]
#
#
#         os.remove(labels_path)
#
#         with open(labels_path, "w+") as labels_file:
#             labels_file.writelines(labels_lines)

# %%
def fix_keypoints(images_list,labels_list, target_size=(256,256)):
    
    transorm = A.Compose([A.Resize(height=target_size[0], width=target_size[1])], keypoint_params=A.KeypointParams(format="xy"))
    
    if type(images_list) != list:
        images_list = [images_list]
        labels_list = [labels_list]
    images_paths = []
    labels_paths = []
    for images_list_path, labels_list_path in zip(images_list, labels_list):
        images_paths_current, labels_paths_current = extract_images_and_labels_paths(images_list_path, labels_list_path)
        images_paths += images_paths_current
        labels_paths +=labels_paths_current

    for image_path, labels_path in zip(images_paths, labels_paths):
        print(image_path)                                                                  
        image = cv2.imread(image_path)
        keypoints = load_keypoints(labels_path, image.shape[1], image.shape[0])
        if keypoints:
            labels_lines = [ " ".join([str(y) for y in keypoint]) + "\n" for keypoint in keypoints]
        else:
            labels_lines = []
        os.remove(labels_path)

        with open(labels_path, "w+") as labels_file:
            labels_file.writelines(labels_lines)

# %%
lists_dir = os.path.join(dataset_dir, "files_lists")
if os.path.exists(lists_dir):
    sh.rmtree(lists_dir)
images_dir = os.path.join(dataset_dir, "Images")
labels_dir = os.path.join(dataset_dir, "Labels") 
metadata_dir = os.path.join(dataset_dir, "Metadata")
os.mkdir(lists_dir)

generate_lists(images_dir, lists_dir, "images", extention="png")
generate_lists(labels_dir, lists_dir, "labels", extention="txt")
generate_lists(labels_dir, lists_dir, "metadata", extention="json")
# Out:
# ../data/dataset/files_lists/Bulk/Stud3 308
# ../data/dataset/files_lists/Bulk/Ptg2 90
# ../data/dataset/files_lists/Bulk/Ptg3 88
# ../data/dataset/files_lists/Bulk/Stud2 684
# ../data/dataset/files_lists/Bulk/Stud4 145
# ../data/dataset/files_lists/Bulk/Ptg1 90
# ../data/dataset/files_lists/Bulk/Stud1 330
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud3 12
# ../data/dataset/files_lists/Agreement/Hidden/Small/Ptg2 10
# ../data/dataset/files_lists/Agreement/Hidden/Small/Ptg3 12
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud2 15
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud4 10
# ../data/dataset/files_lists/Agreement/Hidden/Small/Ptg1 10
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud1 10
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud3 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Ptg2 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Ptg3 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud2 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud4 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Ptg1 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud1 20
# ../data/dataset/files_lists/Agreement/Hidden/Small 0
# ../data/dataset/files_lists/Agreement/Hidden/Large 0
# ../data/dataset/files_lists/Agreement/Explicit/Stud3 10
# ../data/dataset/files_lists/Agreement/Explicit/Ptg2 10
# ../data/dataset/files_lists/Agreement/Explicit/Ptg3 10
# ../data/dataset/files_lists/Agreement/Explicit/Stud2 10
# ../data/dataset/files_lists/Agreement/Explicit/Stud4 10
# ../data/dataset/files_lists/Agreement/Explicit/Ptg1 10
# ../data/dataset/files_lists/Agreement/Explicit/Stud1 10
# ../data/dataset/files_lists/Agreement/Hidden 0
# ../data/dataset/files_lists/Agreement/Explicit 0
# ../data/dataset/files_lists/Bulk 0
# ../data/dataset/files_lists/Agreement 0
# ../data/dataset/files_lists/Bulk/Stud3 308
# ../data/dataset/files_lists/Bulk/Ptg2 90
# ../data/dataset/files_lists/Bulk/Ptg3 88
# ../data/dataset/files_lists/Bulk/Stud2 684
# ../data/dataset/files_lists/Bulk/Stud4 145
# ../data/dataset/files_lists/Bulk/Ptg1 90
# ../data/dataset/files_lists/Bulk/Stud1 330
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud3 12
# ../data/dataset/files_lists/Agreement/Hidden/Small/Ptg2 10
# ../data/dataset/files_lists/Agreement/Hidden/Small/Ptg3 12
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud2 15
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud4 10
# ../data/dataset/files_lists/Agreement/Hidden/Small/Ptg1 10
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud1 10
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud3 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Ptg2 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Ptg3 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud2 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud4 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Ptg1 20
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud1 20
# ../data/dataset/files_lists/Agreement/Hidden/Small 0
# ../data/dataset/files_lists/Agreement/Hidden/Large 0
# ../data/dataset/files_lists/Agreement/Explicit/Stud3 10
# ../data/dataset/files_lists/Agreement/Explicit/Ptg2 10
# ../data/dataset/files_lists/Agreement/Explicit/Ptg3 10
# ../data/dataset/files_lists/Agreement/Explicit/Stud2 10
# ../data/dataset/files_lists/Agreement/Explicit/Stud4 10
# ../data/dataset/files_lists/Agreement/Explicit/Ptg1 10
# ../data/dataset/files_lists/Agreement/Explicit/Stud1 10
# ../data/dataset/files_lists/Agreement/Hidden 0
# ../data/dataset/files_lists/Agreement/Explicit 0
# ../data/dataset/files_lists/Bulk 0
# ../data/dataset/files_lists/Agreement 0
# ../data/dataset/files_lists/Bulk/Stud3 0
# ../data/dataset/files_lists/Bulk/Ptg2 0
# ../data/dataset/files_lists/Bulk/Ptg3 0
# ../data/dataset/files_lists/Bulk/Stud2 0
# ../data/dataset/files_lists/Bulk/Stud4 0
# ../data/dataset/files_lists/Bulk/Ptg1 0
# ../data/dataset/files_lists/Bulk/Stud1 0
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud3 0
# ../data/dataset/files_lists/Agreement/Hidden/Small/Ptg2 0
# ../data/dataset/files_lists/Agreement/Hidden/Small/Ptg3 0
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud2 0
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud4 0
# ../data/dataset/files_lists/Agreement/Hidden/Small/Ptg1 0
# ../data/dataset/files_lists/Agreement/Hidden/Small/Stud1 0
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud3 0
# ../data/dataset/files_lists/Agreement/Hidden/Large/Ptg2 0
# ../data/dataset/files_lists/Agreement/Hidden/Large/Ptg3 0
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud2 0
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud4 0
# ../data/dataset/files_lists/Agreement/Hidden/Large/Ptg1 0
# ../data/dataset/files_lists/Agreement/Hidden/Large/Stud1 0
# ../data/dataset/files_lists/Agreement/Hidden/Small 0
# ../data/dataset/files_lists/Agreement/Hidden/Large 0
# ../data/dataset/files_lists/Agreement/Explicit/Stud3 0
# ../data/dataset/files_lists/Agreement/Explicit/Ptg2 0
# ../data/dataset/files_lists/Agreement/Explicit/Ptg3 0
# ../data/dataset/files_lists/Agreement/Explicit/Stud2 0
# ../data/dataset/files_lists/Agreement/Explicit/Stud4 0
# ../data/dataset/files_lists/Agreement/Explicit/Ptg1 0
# ../data/dataset/files_lists/Agreement/Explicit/Stud1 0
# ../data/dataset/files_lists/Agreement/Hidden 0
# ../data/dataset/files_lists/Agreement/Explicit 0
# ../data/dataset/files_lists/Bulk 0
# ../data/dataset/files_lists/Agreement 0

# %%
images_lists = []
labels_lists = []

for root, dirs, files in os.walk("../data/dataset/files_lists/", topdown=False):
    for name in dirs:
        dir_path = os.path.join(root, name)

        
    for file in files:
        if file.endswith(".txt"):
            if file.startswith("images"):
                images_lists.append(os.path.join(root, file))
            elif file.startswith("labels"):
                labels_lists.append(os.path.join(root, file))
                
fix_keypoints(images_lists, labels_lists) #make them to ints and fix if they are at the border
# Out:
# ../data/dataset/Images/Bulk/Stud3/1031.png
# ../data/dataset/Images/Bulk/Stud3/1035.png
# ../data/dataset/Images/Bulk/Stud3/1037.png
# ../data/dataset/Images/Bulk/Stud3/1081.png
# ../data/dataset/Images/Bulk/Stud3/1126.png
# ../data/dataset/Images/Bulk/Stud3/1154.png
# ../data/dataset/Images/Bulk/Stud3/1251.png
# ../data/dataset/Images/Bulk/Stud3/1264.png
# ../data/dataset/Images/Bulk/Stud3/1265.png
# ../data/dataset/Images/Bulk/Stud3/1277.png
# ../data/dataset/Images/Bulk/Stud3/1348.png
# ../data/dataset/Images/Bulk/Stud3/1350.png
# ../data/dataset/Images/Bulk/Stud3/1370.png
# ../data/dataset/Images/Bulk/Stud3/138.png
# ../data/dataset/Images/Bulk/Stud3/1394.png
# ../data/dataset/Images/Bulk/Stud3/1400.png
# ../data/dataset/Images/Bulk/Stud3/1423.png
# ../data/dataset/Images/Bulk/Stud3/1446.png
# ../data/dataset/Images/Bulk/Stud3/1604.png
# ../data/dataset/Images/Bulk/Stud3/1605.png
# ../data/dataset/Images/Bulk/Stud3/1609.png
# ../data/dataset/Images/Bulk/Stud3/1610.png
# ../data/dataset/Images/Bulk/Stud3/1619.png
# ../data/dataset/Images/Bulk/Stud3/1620.png
# ../data/dataset/Images/Bulk/Stud3/1622.png
# ../data/dataset/Images/Bulk/Stud3/1640.png
# ../data/dataset/Images/Bulk/Stud3/1641.png
# ../data/dataset/Images/Bulk/Stud3/1647.png
# ../data/dataset/Images/Bulk/Stud3/1650.png
# ../data/dataset/Images/Bulk/Stud3/1655.png
# ../data/dataset/Images/Bulk/Stud3/1657.png
# ../data/dataset/Images/Bulk/Stud3/1661.png
# ../data/dataset/Images/Bulk/Stud3/1664.png
# ../data/dataset/Images/Bulk/Stud3/1668.png
# ../data/dataset/Images/Bulk/Stud3/1671.png
# ../data/dataset/Images/Bulk/Stud3/1672.png
# ../data/dataset/Images/Bulk/Stud3/1675.png
# ../data/dataset/Images/Bulk/Stud3/1680.png
# ../data/dataset/Images/Bulk/Stud3/1681.png
# ../data/dataset/Images/Bulk/Stud3/1705.png
# ../data/dataset/Images/Bulk/Stud3/1706.png
# ../data/dataset/Images/Bulk/Stud3/171.png
# ../data/dataset/Images/Bulk/Stud3/5529.png
# ../data/dataset/Images/Bulk/Stud3/5538.png
# ../data/dataset/Images/Bulk/Stud3/5541.png
# ../data/dataset/Images/Bulk/Stud3/5553.png
# ../data/dataset/Images/Bulk/Stud3/5565.png
# ../data/dataset/Images/Bulk/Stud3/5570.png
# ../data/dataset/Images/Bulk/Stud3/5571.png
# ../data/dataset/Images/Bulk/Stud3/5589.png
# ../data/dataset/Images/Bulk/Stud3/56.png
# ../data/dataset/Images/Bulk/Stud3/5742.png
# ../data/dataset/Images/Bulk/Stud3/5805.png
# ../data/dataset/Images/Bulk/Stud3/5854.png
# ../data/dataset/Images/Bulk/Stud3/5885.png
# ../data/dataset/Images/Bulk/Stud3/609.png
# ../data/dataset/Images/Bulk/Stud3/617.png
# ../data/dataset/Images/Bulk/Stud3/66.png
# ../data/dataset/Images/Bulk/Stud3/691.png
# ../data/dataset/Images/Bulk/Stud3/694.png
# ../data/dataset/Images/Bulk/Stud3/697.png
# ../data/dataset/Images/Bulk/Stud3/714.png
# ../data/dataset/Images/Bulk/Stud3/723.png
# ../data/dataset/Images/Bulk/Stud3/725.png
# ../data/dataset/Images/Bulk/Stud3/753.png
# ../data/dataset/Images/Bulk/Stud3/761.png
# ../data/dataset/Images/Bulk/Stud3/814.png
# ../data/dataset/Images/Bulk/Stud3/815.png
# ../data/dataset/Images/Bulk/Stud3/870.png
# ../data/dataset/Images/Bulk/Stud3/900.png
# ../data/dataset/Images/Bulk/Stud3/909.png
# ../data/dataset/Images/Bulk/Stud3/921.png
# ../data/dataset/Images/Bulk/Stud3/93.png
# ../data/dataset/Images/Bulk/Stud3/939.png
# ../data/dataset/Images/Bulk/Stud3/957.png
# ../data/dataset/Images/Bulk/Stud3/958.png
# ../data/dataset/Images/Bulk/Ptg2/108.png
# ../data/dataset/Images/Bulk/Ptg2/1089.png
# ../data/dataset/Images/Bulk/Ptg2/1250.png
# ../data/dataset/Images/Bulk/Ptg2/1263.png
# ../data/dataset/Images/Bulk/Ptg2/129.png
# ../data/dataset/Images/Bulk/Ptg2/1313.png
# ../data/dataset/Images/Bulk/Ptg2/1316.png
# ../data/dataset/Images/Bulk/Ptg2/1332.png
# ../data/dataset/Images/Bulk/Ptg2/134.png
# ../data/dataset/Images/Bulk/Ptg2/1353.png
# ../data/dataset/Images/Bulk/Ptg2/136.png
# ../data/dataset/Images/Bulk/Ptg2/1420.png
# ../data/dataset/Images/Bulk/Ptg2/143.png
# ../data/dataset/Images/Bulk/Ptg2/1458.png
# ../data/dataset/Images/Bulk/Ptg2/1459.png
# ../data/dataset/Images/Bulk/Ptg2/1479.png
# ../data/dataset/Images/Bulk/Ptg2/1490.png
# ../data/dataset/Images/Bulk/Ptg2/1553.png
# ../data/dataset/Images/Bulk/Ptg2/1565.png
# ../data/dataset/Images/Bulk/Ptg2/1585.png
# ../data/dataset/Images/Bulk/Ptg2/1595.png
# ../data/dataset/Images/Bulk/Ptg2/1690.png
# ../data/dataset/Images/Bulk/Ptg2/1740.png
# ../data/dataset/Images/Bulk/Ptg2/1742.png
# ../data/dataset/Images/Bulk/Ptg2/177.png
# ../data/dataset/Images/Bulk/Ptg2/1775.png
# ../data/dataset/Images/Bulk/Ptg2/1778.png
# ../data/dataset/Images/Bulk/Ptg2/1846.png
# ../data/dataset/Images/Bulk/Ptg2/1895.png
# ../data/dataset/Images/Bulk/Ptg2/1959.png
# ../data/dataset/Images/Bulk/Ptg2/1989.png
# ../data/dataset/Images/Bulk/Ptg2/2003.png
# ../data/dataset/Images/Bulk/Ptg2/2216.png
# ../data/dataset/Images/Bulk/Ptg2/2251.png
# ../data/dataset/Images/Bulk/Ptg2/229.png
# ../data/dataset/Images/Bulk/Ptg2/2322.png
# ../data/dataset/Images/Bulk/Ptg2/2324.png
# ../data/dataset/Images/Bulk/Ptg2/2388.png
# ../data/dataset/Images/Bulk/Ptg2/2407.png
# ../data/dataset/Images/Bulk/Ptg2/2426.png
# ../data/dataset/Images/Bulk/Ptg2/2440.png
# ../data/dataset/Images/Bulk/Ptg2/2549.png
# ../data/dataset/Images/Bulk/Ptg2/2577.png
# ../data/dataset/Images/Bulk/Ptg2/2596.png
# ../data/dataset/Images/Bulk/Ptg2/2732.png
# ../data/dataset/Images/Bulk/Ptg2/2760.png
# ../data/dataset/Images/Bulk/Ptg2/288.png
# ../data/dataset/Images/Bulk/Ptg2/2886.png
# ../data/dataset/Images/Bulk/Ptg2/3140.png
# ../data/dataset/Images/Bulk/Ptg2/3260.png
# ../data/dataset/Images/Bulk/Ptg2/3267.png
# ../data/dataset/Images/Bulk/Ptg2/3291.png
# ../data/dataset/Images/Bulk/Ptg2/3491.png
# ../data/dataset/Images/Bulk/Ptg2/3805.png
# ../data/dataset/Images/Bulk/Ptg2/4114.png
# ../data/dataset/Images/Bulk/Ptg2/4121.png
# ../data/dataset/Images/Bulk/Ptg2/4171.png
# ../data/dataset/Images/Bulk/Ptg2/42.png
# ../data/dataset/Images/Bulk/Ptg2/4332.png
# ../data/dataset/Images/Bulk/Ptg2/437.png
# ../data/dataset/Images/Bulk/Ptg2/4409.png
# ../data/dataset/Images/Bulk/Ptg2/4477.png
# ../data/dataset/Images/Bulk/Ptg2/4510.png
# ../data/dataset/Images/Bulk/Ptg2/4558.png
# ../data/dataset/Images/Bulk/Ptg2/4568.png
# ../data/dataset/Images/Bulk/Ptg2/4575.png
# ../data/dataset/Images/Bulk/Ptg2/4594.png
# ../data/dataset/Images/Bulk/Ptg2/4609.png
# ../data/dataset/Images/Bulk/Ptg2/4613.png
# ../data/dataset/Images/Bulk/Ptg2/4670.png
# ../data/dataset/Images/Bulk/Ptg2/4778.png
# ../data/dataset/Images/Bulk/Ptg2/4978.png
# ../data/dataset/Images/Bulk/Ptg2/4990.png
# ../data/dataset/Images/Bulk/Ptg2/506.png
# ../data/dataset/Images/Bulk/Ptg2/5118.png
# ../data/dataset/Images/Bulk/Ptg2/5305.png
# ../data/dataset/Images/Bulk/Ptg2/5410.png
# ../data/dataset/Images/Bulk/Ptg2/5502.png
# ../data/dataset/Images/Bulk/Ptg2/558.png
# ../data/dataset/Images/Bulk/Ptg2/5611.png
png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud3/4511.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud3/5063.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud3/5760.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/1857.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/1940.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/1980.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/2170.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/2417.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/2535.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/2614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/2631.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/2651.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/2669.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/2709.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/2716.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/3614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/3749.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/3906.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/4036.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/4310.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/4511.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/5063.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg2/5760.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/1857.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/1940.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/1980.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/2170.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/2417.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/2535.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/2614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/2631.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/2651.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/2669.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/2709.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/2716.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/3614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/3749.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/3906.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/4036.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/4310.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/4511.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/5063.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg3/5760.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/1857.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/1940.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/1980.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/2170.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/2417.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/2535.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/2614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/2631.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/2651.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/2669.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/2709.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/2716.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/3614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/3749.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/3906.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/4036.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/4310.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/4511.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/5063.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud2/5760.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/1857.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/1940.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/1980.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/2170.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/2417.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/2535.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/2614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/2631.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/2651.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/2669.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/2709.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/2716.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/3614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/3749.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/3906.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/4036.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/4310.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/4511.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/5063.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud4/5760.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/1857.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/1940.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/1980.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/2170.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/2417.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/2535.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/2614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/2631.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/2651.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/2669.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/2709.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/2716.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/3614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/3749.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/3906.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/4036.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/4310.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/4511.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/5063.png
# ../data/dataset/Images/Agreement/Hidden/Large/Ptg1/5760.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/1857.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/1940.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/1980.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/2170.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/2417.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/2535.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/2614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/2631.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/2651.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/2669.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/2709.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/2716.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/3614.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/3749.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/3906.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/4036.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/4310.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/4511.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/5063.png
# ../data/dataset/Images/Agreement/Hidden/Large/Stud1/5760.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/1060.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/1314.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/240.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/318.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/489.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/575.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/582.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/709.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/913.png
# ../data/dataset/Images/Agreement/Explicit/Stud3/948.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/1060.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/1314.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/240.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/318.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/489.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/575.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/582.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/709.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/913.png
# ../data/dataset/Images/Agreement/Explicit/Ptg2/948.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/1060.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/1314.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/240.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/318.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/489.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/575.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/582.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/709.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/913.png
# ../data/dataset/Images/Agreement/Explicit/Ptg3/948.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/1060.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/1314.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/240.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/318.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/489.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/575.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/582.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/709.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/913.png
# ../data/dataset/Images/Agreement/Explicit/Stud2/948.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/1060.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/1314.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/240.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/318.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/489.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/575.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/582.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/709.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/913.png
# ../data/dataset/Images/Agreement/Explicit/Stud4/948.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/1060.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/1314.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/240.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/318.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/489.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/575.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/582.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/709.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/913.png
# ../data/dataset/Images/Agreement/Explicit/Ptg1/948.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/1060.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/1314.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/240.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/318.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/489.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/575.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/582.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/709.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/913.png
# ../data/dataset/Images/Agreement/Explicit/Stud1/948.png

# %%
MASTER_YML_PATH = "../data/master_ymls/everything.yaml"

# %%
tp = "../data/dataset/files_lists/"

# %%
os.path.normpath(os.path.relpath(MASTER_YML_PATH, tp))
# Out:
# '../../master_ymls/everything.yaml'

# %%
images_lists = []
labels_lists = []
for root, dirs, files in os.walk("../data/dataset/files_lists/", topdown=False):
    for name in dirs:
        dir_path = os.path.join(root, name)

        
    for file in files:
        if file.endswith(".txt"):
            rel_path = os.path.join(root, file)
            rel_path = os.path.normpath(os.path.relpath(rel_path,os.path.dirname(MASTER_YML_PATH)))
            if file.startswith("images"):
                images_lists.append(rel_path)
            elif file.startswith("labels"):
                labels_lists.append(rel_path)

# %%
lists = {
    "images_lists": images_lists,
    "labels_lists": labels_lists
}

with open("../data/master_ymls/everything.yaml", "w+") as file:
    yaml.safe_dump(lists, file)

# %%
with open("../data/master_ymls/unique.yaml", "r") as file:
    load = yaml.safe_load(file)
